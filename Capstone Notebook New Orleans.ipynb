# %% [markdown]
# <h2>Applied Data Science - Capstone Project: Entertainment in Neighborhoods of New Orleans<h2/>

# %% [markdown]
# <h3>Introduction and problem description<h3/>

# %% [markdown]
# For this project, I would like to group neighborhoods of New Orleans, LA, based on accessability and popularity of art and entertainment venues in that neighborhoods. I would like to be able to make recommendations of places to hang out and spend leasue time to people that would like to visit the city, based on their preferences for entertainment.

# %% [markdown]
# <h3>Data description<h3/>

# %% [markdown]
# I will use the data obtained from Wikipedia, containing a list of New Orleans neighborhoods, with coordinates for each. There are 72 neighborhoods listed on the Wiki page. From Foursquare API I will get a list of most common types of venues in each neighborhood that are related to art and entertainment and then will apply the k-means algorithm to cluster neighborhoods. For each cluster I will try to assess some characteristics. Based on those characteristics I will try to recommend which areas would be the most suitable for turists and visitors based on their preferences.

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>Data scarpping - Wikipedia - New Orleans Neighborhoods with coordinates <h3/>

# %% [markdown]
# Importing BeautifulSoup package and opening Wikipedia URL with the table

# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen

# %%
url = "https://en.wikipedia.org/wiki/Neighborhoods_in_New_Orleans"
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')

# %% [markdown]
# Scrapping Wikipage: Locating table object on Wiki page and saving it to dataframe

# %%
table=soup.find_all('table', class_="wikitable")[0] 


rows = table.findAll('tr')

import re
list_rows = []
for row in rows:
    clean2 = re.sub('\n','',
                    str(re.sub('</td>',':',
                    str(re.sub('<td>','',
                    str(re.sub('</tr>','',
                    str(re.sub('<tr>', '',str(row))))))))))
    list_rows.append(clean2)

list_rows=list_rows[1:]


df_list = pd.DataFrame(list_rows)

df = df_list[0].str.split(':', expand=True)
df=df.iloc[0:,0:3]

df.columns=['Neighborhood', 'Longitude', 'Latitude']
df['Longitude'] = pd.to_numeric(df['Longitude'])
df['Latitude'] = pd.to_numeric(df['Latitude'] )

df.head(10)
# Out:
#       Neighborhood  Longitude   Latitude
# 0  U.S. NAVAL BASE -90.026093  29.946085
# 1    ALGIERS POINT -90.051606  29.952462
# 2          WHITNEY -90.042357  29.947200
# 3          AUDUBON -90.121450  29.932994
# 4       OLD AURORA -90.000000  29.924440
# 5     B. W. COOPER -90.091753  29.951774
# 6   BAYOU ST. JOHN -90.086517  29.976071
# 7          BEHRMAN -90.026436  29.934817
# 8      BLACK PEARL -90.134883  29.935895
# 9        BROADMOOR -90.103812  29.946568

# %% [markdown]
# <h3>Analyzing neighborhoods of New Orleans with Foursquare API<h3/>

# %% [markdown]
# From Foursquare API I will obtain information about venues related to art and entertainment in each neighborhood.
# Importing required libraries.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.4.5.2         |   py36h9f0ad1d_0         152 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.4.5.2 |       hecda079_0         147 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.2-hecda079_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.2-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2020.4.5.2   | 152 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# ca-certificates-2020 | 147 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Plotting map of New Orleans Neighborhoods

# %%
#New Orleans Coordinates
latitude = 29.9511
longitude = -90.0715

map_orleans = folium.Map(location=[latitude, longitude], zoom_start=13)


# add markers to map
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_orleans)  
    
map_orleans
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Neighborhood exploration with Foursquare API: importing libraries and setting up API credentials

# %%
#Foursquare Data
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

#Foursquare credentials
VERSION = '20180604'
LIMIT = 100
CATEGORYID="4d4b7104d754a06370d81259" #Art&Entertainment Category

# %% [markdown]
# Obtaining information about venues in each neighborhood of New Orleans from Foursquare API

# %%
#Function to explore neighborhood in New Orleans
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            CATEGORYID,
            LIMIT)
         
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],  
            v['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

#calling function on df dataframe
new_orleans_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )

new_orleans_venues.head()
# Out:
# U.S. NAVAL BASE
# ALGIERS POINT
# WHITNEY
# AUDUBON
# OLD AURORA
# B. W. COOPER
# BAYOU ST. JOHN
# BEHRMAN
# BLACK PEARL
# BROADMOOR
# MARLYVILLE - FONTAINEBLEAU
# GERT TOWN
# MID-CITY
# ST. CLAUDE
# CENTRAL BUSINESS DISTRICT
# FRENCH QUARTER
# CENTRAL CITY
# LAKE CATHERINE
# VILLAGE DE LEST
# VIAVANT - VENETIAN ISLES
# NEW AURORA - ENGLISH TURN
# TALL TIMBERS - BRECHTEL
# FISCHER DEV
# McDONOGH
# LOWER GARDEN DISTRICT
# ST. THOMAS DEV
# EAST RIVERSIDE
# IRISH CHANNEL
# TOURO
# MILAN
# UPTOWN
# WEST RIVERSIDE
# EAST CARROLLTON
# FRERET
# GARDEN DISTRICT
# LEONIDAS
# HOLLYGROVE
# TULANE - GRAVIER
# TREME - LAFITTE
# SEVENTH WARD
# MARIGNY
# ST. ROCH
# DIXON
# LAKEWOOD
# NAVARRE
# CITY PARK
# LAKEVIEW
# WEST END
# LAKESHORE - LAKE VISTA
# FILMORE
# ST. BERNARD AREA
# DILLARD
# ST.   ANTHONY
# LAKE TERRACE &amp; OAKS
# MILNEBURG
# PONTCHARTRAIN PARK
# GENTILLY WOODS
# GENTILLY TERRACE
# DESIRE AREA
# FLORIDA AREA
# FLORIDA DEV
# LOWER NINTH WARD
# BYWATER
# HOLY CROSS
# PINES VILLAGE
# PLUM ORCHARD
# READ BLVD WEST
# READ BLVD EAST
# WEST LAKE FOREST
# LITTLE WOODS
# FAIRGROUNDS
# IBERVILLE
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  U.S. NAVAL BASE              29.946085              -90.026093
# 1    ALGIERS POINT              29.952462              -90.051606
# 2    ALGIERS POINT              29.952462              -90.051606
# 3    ALGIERS POINT              29.952462              -90.051606
# 4    ALGIERS POINT              29.952462              -90.051606
#
#                  Venue  Venue Latitude  Venue Longitude         Venue Category
# 0    Olive Branch B.C.       29.942959       -90.021953  General Entertainment
# 1        Algiers Point       29.951410       -90.052207          Historic Site
# 2          NOLA Potter       29.951946       -90.051021            Art Gallery
# 3  Algiers Point Tours       29.952759       -90.052636          Tour Provider
# 4    Jazz Walk Of Fame       29.952244       -90.055080          Historic Site

# %% [markdown]
# Dataframe preparations for k-means: grouping dataset by neighborhood and taking the mean of the frequency fo ocuurance of each venue category.
# Only top 10 venues types in each neighborhood are considered.

# %%
#Data frame preps for K-means
# one hot encoding
new_orleans_onehot = pd.get_dummies(new_orleans_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
new_orleans_onehot['Neighborhood'] = new_orleans_venues['Neighborhood'] 

# move neighborhood column to the first column
first_col = new_orleans_onehot .pop('Neighborhood')
new_orleans_onehot .insert(0, 'Neighborhood', first_col)

#group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
new_orleans_grouped = new_orleans_onehot.groupby('Neighborhood').mean().reset_index()

#function to sort venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

#Top 20 venues per each neighborhood	
num_top_venues = 10

indicators = ['st', 'nd', 'rd']#used to adress 1st, 2nd or 3rd

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = new_orleans_grouped['Neighborhood']

for ind in np.arange(new_orleans_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(new_orleans_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#      Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 0   ALGIERS POINT         Historic Site            Art Gallery
# 1         AUDUBON                Arcade  General Entertainment
# 2    B. W. COOPER            Theme Park            Zoo Exhibit
# 3  BAYOU ST. JOHN           Art Gallery         History Museum
# 4         BEHRMAN            Art Museum           Concert Hall
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                Arcade             Jazz Club                Music Venue
# 1               Theater          Concert Hall             History Museum
# 2    Country Dance Club           Coffee Shop  College Academic Building
# 3          Concert Hall         Tour Provider      General Entertainment
# 4           Zoo Exhibit          Dance Studio  College Academic Building
#
#    6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 0         History Museum               Theater              Tour Provider
# 1              Rock Club         Indie Theater      College Arts Building
# 2  College Arts Building       College Theater                Comedy Club
# 3                 Casino            Public Art  College Academic Building
# 4  College Arts Building       College Theater                Comedy Club
#
#        9th Most Common Venue 10th Most Common Venue
# 0  College Academic Building            Gas Station
# 1              Historic Site            Art Gallery
# 2               Concert Hall           Dance Studio
# 3      College Arts Building        College Theater
# 4         Country Dance Club               Dive Bar

# %% [markdown]
# Running k-means with k=3. Neighborhoods are grouped into clusters based on the similarities in values types availability/presence.
# After assessing how neighborhoods are clustered, dataframe with all neighborhoods listed, along with most common venues types and assignment to one of k-means clusters is created.

# %%
#K-means
# set number of clusters
kclusters = 3

new_orleans_grouped_clustering = new_orleans_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(new_orleans_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_

#new dataframe that includes the cluster as well as the top 10 venues for each neighborhood
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

new_orleans_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
new_orleans_merged = new_orleans_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
new_orleans_merged= new_orleans_merged[new_orleans_merged['1st Most Common Venue'].notnull()]
new_orleans_merged['Cluster Labels'] = pd.to_numeric(new_orleans_merged['Cluster Labels'],downcast='integer')
new_orleans_merged.head()
# Out:
#       Neighborhood  Longitude   Latitude  Cluster Labels  \
# 0  U.S. NAVAL BASE -90.026093  29.946085               1
# 1    ALGIERS POINT -90.051606  29.952462               0
# 2          WHITNEY -90.042357  29.947200               0
# 3          AUDUBON -90.121450  29.932994               2
# 4       OLD AURORA -90.000000  29.924440               2
#
#    1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0  General Entertainment            Zoo Exhibit          Dance Studio
# 1          Historic Site            Art Gallery                Arcade
# 2  Performing Arts Venue  General Entertainment           Art Gallery
# 3                 Arcade  General Entertainment               Theater
# 4             Theme Park           Concert Hall           Zoo Exhibit
#
#        4th Most Common Venue  5th Most Common Venue  \
# 0  College Academic Building  College Arts Building
# 1                  Jazz Club            Music Venue
# 2         Country Dance Club            Coffee Shop
# 3               Concert Hall         History Museum
# 4         Country Dance Club            Coffee Shop
#
#        6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 0            College Theater            Comedy Club           Concert Hall
# 1             History Museum                Theater          Tour Provider
# 2  College Academic Building  College Arts Building        College Theater
# 3                  Rock Club          Indie Theater  College Arts Building
# 4  College Academic Building  College Arts Building        College Theater
#
#        9th Most Common Venue 10th Most Common Venue
# 0         Country Dance Club               Dive Bar
# 1  College Academic Building            Gas Station
# 2                Comedy Club           Concert Hall
# 3              Historic Site            Art Gallery
# 4                Comedy Club           Dance Studio

# %% [markdown]
# Creating map with New Orleans neighborhoods clusters.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(new_orleans_merged['Latitude'], new_orleans_merged['Longitude'], new_orleans_merged['Neighborhood'], new_orleans_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3>Conclusions<h3/>

# %% [markdown]
# As the results of clusters analysis below, we can assess that in cluster #1 there are art galleries, public arts, exhibits, jazz clubs, historic sites, museums. So if someone would be interested in maybe more formal forms of entertainment, in art or historic sites, neighborhoods from cluster #1 would be appropriate places to visit or stay in.
# In cluster #2 zoo exhibits, comedy clubs, concert halls and colleage-related venues are popular, like theaters, or art bulding. Neighborhoods from that cluster may be of interest for students, concerts lovers and animals enthusiasts.
# Neighborhoods from cluster #3 would be interesting for people looking for more casual entertainment, that like music, dancing, movies, as the following types of entertainment venues are popular in cluster #3: dance studios, music venues, concert halls, indie theaters, movie theaters, country dance clubs.

# %% [markdown]
# Exploring cluster #1

# %%
#Exploring cluster #1
new_orleans_merged.loc[new_orleans_merged['Cluster Labels'] == 0, new_orleans_merged.columns[[0] + list(range(4, new_orleans_merged.shape[1]))]]
# Out:
#                  Neighborhood  1st Most Common Venue  2nd Most Common Venue  \
# 1               ALGIERS POINT          Historic Site            Art Gallery
# 2                     WHITNEY  Performing Arts Venue  General Entertainment
# 6              BAYOU ST. JOHN            Art Gallery         History Museum
# 9                   BROADMOOR  General Entertainment          Indie Theater
# 14  CENTRAL BUSINESS DISTRICT            Art Gallery            Music Venue
# 15             FRENCH QUARTER            Art Gallery              Jazz Club
# 20  NEW AURORA - ENGLISH TURN                Theater            Music Venue
# 23                   McDONOGH  Performing Arts Venue            Art Gallery
# 24      LOWER GARDEN DISTRICT  General Entertainment           Dance Studio
# 25             ST. THOMAS DEV              Piano Bar                 Shrine
# 26             EAST RIVERSIDE            Art Gallery            Zoo Exhibit
# 27              IRISH CHANNEL           Dance Studio            Art Gallery
# 28                      TOURO            Art Gallery  General Entertainment
# 30                     UPTOWN            Music Venue  General Entertainment
# 31             WEST RIVERSIDE                 School            Art Gallery
# 32            EAST CARROLLTON            Art Gallery  General Entertainment
# 33                     FRERET            Art Gallery  Performing Arts Venue
# 34            GARDEN DISTRICT          Historic Site            Art Gallery
# 35                   LEONIDAS            Art Gallery  General Entertainment
# 38            TREME - LAFITTE  General Entertainment            Art Gallery
# 39               SEVENTH WARD            Art Gallery                 Lounge
# 40                    MARIGNY            Art Gallery              Jazz Club
# 42                      DIXON  Performing Arts Venue  General Entertainment
# 43                   LAKEWOOD           Dance Studio  General Entertainment
# 62                    BYWATER            Art Gallery  General Entertainment
# 63                 HOLY CROSS          Historic Site            Art Gallery
# 70                FAIRGROUNDS            Music Venue              Jazz Club
# 71                  IBERVILLE            Music Venue  General Entertainment
#
#                        3rd Most Common Venue 4th Most Common Venue  \
# 1                                     Arcade             Jazz Club
# 2                                Art Gallery    Country Dance Club
# 6                               Concert Hall         Tour Provider
# 9                                Music Venue           Zoo Exhibit
# 14                     General Entertainment         Historic Site
# 15                             Historic Site        History Museum
# 20                               Zoo Exhibit    Country Dance Club
# 23                              Concert Hall          Dance Studio
# 24                     Performing Arts Venue           Music Venue
# 25                               Music Venue            Public Art
# 26  Residential Building (Apartment / Condo)                Circus
# 27                               Music Venue    Country Dance Club
# 28                             Historic Site            Public Art
# 30                                   Exhibit            Theme Park
# 31                               Music Venue               Exhibit
# 32                               Comedy Club             Rock Club
# 33                                 Jazz Club                Arcade
# 34                     General Entertainment            Public Art
# 35                               Coffee Shop       Other Nightlife
# 38                             Historic Site             Jazz Club
# 39                               Zoo Exhibit          Dance Studio
# 40                     General Entertainment           Music Venue
# 42                               Comedy Club           Music Venue
# 43                               Music Venue    Country Dance Club
# 62                               Music Venue         Indie Theater
# 63                      Arts & Entertainment          Concert Hall
# 70                     General Entertainment          Concert Hall
# 71                               Art Gallery        History Museum
#
#                        5th Most Common Venue      6th Most Common Venue  \
# 1                                Music Venue             History Museum
# 2                                Coffee Shop  College Academic Building
# 6                      General Entertainment                     Casino
# 9                         Country Dance Club  College Academic Building
# 14                                 Jazz Club               Concert Hall
# 15                             Tour Provider                     Museum
# 20                 College Academic Building      College Arts Building
# 23                               Gas Station             Farmers Market
# 24                             Historic Site               Concert Hall
# 25                             Historic Site                Art Gallery
# 26                     General Entertainment                Gas Station
# 27                 College Academic Building      College Arts Building
# 28  Residential Building (Apartment / Condo)               Dance Studio
# 30                                   Theater              Historic Site
# 31                             Historic Site      General Entertainment
# 32                             Historic Site                        Bar
# 33                               Music Venue      General Entertainment
# 34                                 Rock Club         Basketball Stadium
# 35                                    Office                Comedy Club
# 38                               Music Venue                     Museum
# 39                 College Academic Building      College Arts Building
# 40                                   Theater             History Museum
# 42                              Concert Hall                Coffee Shop
# 43                 College Academic Building      College Arts Building
# 62                                       Bar                 Public Art
# 63                                  Dive Bar      College Arts Building
# 70                                 Racetrack  College Academic Building
# 71                             Historic Site               Concert Hall
#
#         7th Most Common Venue      8th Most Common Venue  \
# 1                     Theater              Tour Provider
# 2       College Arts Building            College Theater
# 6                  Public Art  College Academic Building
# 9       College Arts Building            College Theater
# 14          Outdoor Sculpture      Performing Arts Venue
# 15      Performing Arts Venue                        Bar
# 20            College Theater                Comedy Club
# 23                    Exhibit                Event Space
# 24                Art Gallery                  Rock Club
# 25                 Art Museum                Coffee Shop
# 26             Farmers Market                    Exhibit
# 27            College Theater                Comedy Club
# 28                    Theater        Indie Movie Theater
# 30                Art Gallery                 Water Park
# 31             Farmers Market                Gas Station
# 32      Performing Arts Venue            Other Nightlife
# 33                Comedy Club               Concert Hall
# 34                Comedy Club                     Casino
# 35               Concert Hall                  Rock Club
# 38            Bed & Breakfast               Dance Studio
# 39            College Theater                Comedy Club
# 40              Historic Site              Indie Theater
# 42  College Academic Building      College Arts Building
# 43            College Theater                Comedy Club
# 62         Country Dance Club      College Arts Building
# 63            College Theater                Comedy Club
# 70      College Arts Building            College Theater
# 71      Performing Arts Venue              Tour Provider
#
#         9th Most Common Venue     10th Most Common Venue
# 1   College Academic Building                Gas Station
# 2                 Comedy Club               Concert Hall
# 6       College Arts Building            College Theater
# 9                 Comedy Club               Concert Hall
# 14                     Museum                      Plaza
# 15  Cajun / Creole Restaurant                     Church
# 20               Concert Hall               Dance Studio
# 23                   Dive Bar               Cocktail Bar
# 24                 Public Art                Event Space
# 25                Gas Station             Farmers Market
# 26                Event Space                   Dive Bar
# 27               Concert Hall                Zoo Exhibit
# 28                     Circus             Farmers Market
# 30        Indie Movie Theater                Event Space
# 31                Event Space                   Dive Bar
# 32                   Aquarium                    Exhibit
# 33                  Rock Club       Other Great Outdoors
# 34              Movie Theater               Dance Studio
# 35         Country Dance Club               Dance Studio
# 38         Country Dance Club            College Theater
# 39               Concert Hall         Country Dance Club
# 40                  Rock Club      Performing Arts Venue
# 42            College Theater                Zoo Exhibit
# 43               Concert Hall                Zoo Exhibit
# 62            College Theater                Comedy Club
# 63         Country Dance Club               Dance Studio
# 70                Comedy Club         Country Dance Club
# 71               Dance Studio  Cajun / Creole Restaurant

# %% [markdown]
# Exploring cluster #2

# %%
new_orleans_merged.loc[new_orleans_merged['Cluster Labels'] == 1, new_orleans_merged.columns[[0] + list(range(4, new_orleans_merged.shape[1]))]]
# Out:
#                Neighborhood  1st Most Common Venue      2nd Most Common Venue  \
# 0           U.S. NAVAL BASE  General Entertainment                Zoo Exhibit
# 11                GERT TOWN  General Entertainment              Bowling Alley
# 45                CITY PARK  Performing Arts Venue      General Entertainment
# 53  LAKE TERRACE &amp; OAKS  General Entertainment  College Academic Building
#
#    3rd Most Common Venue      4th Most Common Venue  \
# 0           Dance Studio  College Academic Building
# 11           Zoo Exhibit         Country Dance Club
# 45    Country Dance Club                Coffee Shop
# 53       College Theater                Zoo Exhibit
#
#         5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0       College Arts Building        College Theater           Comedy Club
# 11  College Academic Building  College Arts Building       College Theater
# 45  College Academic Building  College Arts Building       College Theater
# 53               Dance Studio  College Arts Building           Comedy Club
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Concert Hall    Country Dance Club               Dive Bar
# 11           Comedy Club          Concert Hall           Dance Studio
# 45           Comedy Club          Concert Hall            Zoo Exhibit
# 53          Concert Hall    Country Dance Club               Dive Bar

# %% [markdown]
# Exploring cluster #3

# %%
new_orleans_merged.loc[new_orleans_merged['Cluster Labels'] == 2,new_orleans_merged.columns[[0] + list(range(4, new_orleans_merged.shape[1]))]]
# Out:
#                   Neighborhood  1st Most Common Venue  2nd Most Common Venue  \
# 3                      AUDUBON                 Arcade  General Entertainment
# 4                   OLD AURORA             Theme Park           Concert Hall
# 5                 B. W. COOPER             Theme Park            Zoo Exhibit
# 7                      BEHRMAN             Art Museum           Concert Hall
# 8                  BLACK PEARL          Movie Theater  General Entertainment
# 10  MARLYVILLE - FONTAINEBLEAU            Zoo Exhibit          Movie Theater
# 12                    MID-CITY          Historic Site  General Entertainment
# 13                  ST. CLAUDE                 Museum  General Entertainment
# 16                CENTRAL CITY             Public Art     Basketball Stadium
# 29                       MILAN  General Entertainment                 Arcade
# 41                    ST. ROCH  Performing Arts Venue            Gas Station
# 44                     NAVARRE           Concert Hall  General Entertainment
# 46                    LAKEVIEW           Dance Studio          Historic Site
# 47                    WEST END          Historic Site             Public Art
# 49                     FILMORE          Indie Theater       Baseball Stadium
# 51                     DILLARD                Theater            Zoo Exhibit
# 54                   MILNEBURG              Pool Hall            Zoo Exhibit
#
#     3rd Most Common Venue  4th Most Common Venue      5th Most Common Venue  \
# 3                 Theater           Concert Hall             History Museum
# 4             Zoo Exhibit     Country Dance Club                Coffee Shop
# 5      Country Dance Club            Coffee Shop  College Academic Building
# 7             Zoo Exhibit           Dance Studio  College Academic Building
# 8        Baseball Stadium  Performing Arts Venue         Country Dance Club
# 10                 Arcade                Stadium                 Salsa Club
# 12          Movie Theater               Building                  Jazz Club
# 13          Indie Theater            Zoo Exhibit  College Academic Building
# 16          Indie Theater  Performing Arts Venue               Concert Hall
# 29                Theater             Public Art                Zoo Exhibit
# 41     Country Dance Club            Coffee Shop  College Academic Building
# 44          Movie Theater            Music Venue      Performing Arts Venue
# 46              Multiplex  General Entertainment                 Theme Park
# 47           Cocktail Bar            Coffee Shop  College Academic Building
# 49  Performing Arts Venue            Zoo Exhibit         Country Dance Club
# 51     Country Dance Club            Coffee Shop  College Academic Building
# 54                 Circus            Coffee Shop  College Academic Building
#
#         6th Most Common Venue      7th Most Common Venue  \
# 3                   Rock Club              Indie Theater
# 4   College Academic Building      College Arts Building
# 5       College Arts Building            College Theater
# 7       College Arts Building            College Theater
# 8   College Academic Building      College Arts Building
# 10  College Academic Building      College Arts Building
# 12                        Pub         Basketball Stadium
# 13      College Arts Building            College Theater
# 16                Coffee Shop  College Academic Building
# 29         Country Dance Club  College Academic Building
# 41      College Arts Building            College Theater
# 44                Event Space                   Dive Bar
# 46                    Theater                Comedy Club
# 47      College Arts Building            College Theater
# 49  College Academic Building      College Arts Building
# 51      College Arts Building            College Theater
# 54      College Arts Building            College Theater
#
#         8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 3       College Arts Building          Historic Site            Art Gallery
# 4             College Theater            Comedy Club           Dance Studio
# 5                 Comedy Club           Concert Hall           Dance Studio
# 7                 Comedy Club     Country Dance Club               Dive Bar
# 8             College Theater            Comedy Club           Concert Hall
# 10            College Theater            Comedy Club           Concert Hall
# 12                Music Venue                    Bar           Concert Hall
# 13                Comedy Club           Concert Hall     Country Dance Club
# 16      College Arts Building        College Theater            Comedy Club
# 29      College Arts Building        College Theater            Comedy Club
# 41                Comedy Club           Concert Hall            Zoo Exhibit
# 44               Dance Studio                Exhibit          Go Kart Track
# 46  College Academic Building  College Arts Building        College Theater
# 47                Comedy Club           Concert Hall            Zoo Exhibit
# 49            College Theater            Comedy Club           Concert Hall
# 51                Comedy Club           Concert Hall           Dance Studio
# 54                Comedy Club           Concert Hall     Country Dance Club
